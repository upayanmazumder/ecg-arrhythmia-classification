# %%
# 🩺 ECG Arrhythmia Classification — EDA

# --- Imports ---
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# --- Load Dataset ---
# TODO: replace with your dataset path
df = pd.read_csv("../data/kaggle/data.csv")
df.head()

# --- Basic Info ---
df.info()
df.describe()

# --- Check for Missing Values ---
df.isnull().sum()

# --- Class Distribution ---
plt.figure(figsize=(6,4))
sns.countplot(x='label', data=df)
plt.title("Class Distribution")
plt.show()

# --- Example Signal Plot (if signals available) ---
# TODO: Uncomment and modify if you have raw ECG signals
# plt.plot(df.iloc[0, :-1])
# plt.title(f"Sample ECG - Label: {df.iloc[0, -1]}")
# plt.show()
